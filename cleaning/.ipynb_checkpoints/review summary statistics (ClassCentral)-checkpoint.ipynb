# %%
import csv
import datetime

# %%
## read course Data set
courseList = []
with open("./MOOC_data/xtData/(cleand)ClassCentral_course.csv", "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        courseList.append(row)
        
print(len(courseList))
# Out:
# 3153

# %%
## read review Data set
reviewList = []
with open("./MOOC_data/xtData/(Date_Adjusted)ClassCentral_review_renewed.csv", "r") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        reviewList.append(row)
print(len(reviewList))
# Out:
# 20903

# %%
## review statistics init
statistics = []
for t in range(1,5):
    statistics.append(dict({
        "time": t,
        "num_review": 0,
        "num_review_with_id":0,
        "num_low_star":0,
        "num_mid_star":0,
        "num_high_star":0,
        "sum_review_length":0,
        "sum_review_rating":0,
        "courses": [],
        "num_courses": 0,    
        
    }))

# %%
for review in reviewList:
    
    temp_review_value = int(review['single_rating_value'])
    date = datetime.datetime.strptime(review['review_date'], "%Y-%m-%d") 
    
    if date.year == 2013:
        # T1: 
        if date.month > 6 and date.month <= 12:
            statistics[0]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[0]['num_review_with_id'] += 1
                
            statistics[0]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[0]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[0]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[0]['num_mid_star'] += 1
            else:
                statistics[0]['num_high_star'] += 1
                
            if review['url'] not in statistics[0]['courses']:
                statistics[0]['courses'].append(review['url'])

    elif date.year == 2014:

        if date.month > 0 and date.month < 7:
            statistics[0]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[0]['num_review_with_id'] += 1
                
            statistics[0]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[0]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[0]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[0]['num_mid_star'] += 1
            else:
                statistics[0]['num_high_star'] += 1
                
            if review['url'] not in statistics[0]['courses']:
                statistics[0]['courses'].append(review['url'])
        # T2: 
        else:
            statistics[1]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[1]['num_review_with_id'] += 1
                
            statistics[1]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[1]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[1]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[1]['num_mid_star'] += 1
            else:
                statistics[1]['num_high_star'] += 1
            
            if review['url'] not in statistics[1]['courses']:
                statistics[1]['courses'].append(review['url'])
                
    elif date.year == 2015:
        
        if date.month > 0 and date.month < 7:
            statistics[1]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[1]['num_review_with_id'] += 1
                
            statistics[1]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[1]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[1]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[1]['num_mid_star'] += 1
            else:
                statistics[1]['num_high_star'] += 1
                
                
            if review['url'] not in statistics[1]['courses']:
                statistics[1]['courses'].append(review['url'])
                
        # T3: 
        else:
            statistics[2]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[2]['num_review_with_id'] += 1
                
            statistics[2]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[2]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[2]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[2]['num_mid_star'] += 1
            else:
                statistics[2]['num_high_star'] += 1
                
            if review['url'] not in statistics[2]['courses']:
                statistics[2]['courses'].append(review['url'])
                
    elif date.year == 2016:

        if date.month > 0 and date.month < 7:
            statistics[2]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[2]['num_review_with_id'] += 1
                
            statistics[2]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[2]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[2]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[2]['num_mid_star'] += 1
            else:
                statistics[2]['num_high_star'] += 1
                
            if review['url'] not in statistics[2]['courses']:
                statistics[2]['courses'].append(review['url'])
                
        # T4: 
        else:
            statistics[3]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[3]['num_review_with_id'] += 1
                
            statistics[3]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[3]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[3]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[3]['num_mid_star'] += 1
            else:
                statistics[3]['num_high_star'] += 1
                
            if review['url'] not in statistics[3]['courses']:
                statistics[3]['courses'].append(review['url'])
                
    elif date.year == 2017:

        if date.month > 0 and date.month < 7:
            statistics[3]['num_review'] += 1
            if(review['reviewer_url'] != "null"):
                statistics[3]['num_review_with_id'] += 1
                
            statistics[3]['sum_review_rating'] += int(review['single_rating_value'])
            statistics[3]['sum_review_length'] += int(len(review['review_contents']))
                        
            if temp_review_value > 0 and temp_review_value < 3:
                statistics[3]['num_low_star'] += 1
            elif temp_review_value == 3:
                statistics[3]['num_mid_star'] += 1
            else:
                statistics[3]['num_high_star'] += 1
                
            if review['url'] not in statistics[3]['courses']:
                statistics[3]['courses'].append(review['url'])

# %%
for stat in statistics:
    stat['num_courses'] = len(stat['courses'])

# %%
for review in reviewList:
        
        temp_review_value = int(review['single_rating_value'])
        
        
        # review데이터의 course_url 과 course데이터의 url이 일치할 경우 review_count(tx)/review_value(tx)값 증가
        if review['url'] == course['url']:
                    
            date = datetime.datetime.strptime(review['review_date'], "%Y-%m-%d") 
           
            if date.year == 2013:
                # T1: 
                if date.month > 6 and date.month <= 12:
                    courseList[index]['review_count(t1)'] += 1
                    courseList[index]['review_value(t1)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t1)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t1)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t1)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t1)'] += 1
                    else:
                        courseList[index]['high_review_count(t1)'] += 1
                                
            elif date.year == 2014:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t1)'] += 1
                    courseList[index]['review_value(t1)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t1)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t1)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t1)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t1)'] += 1
                    else:
                        courseList[index]['high_review_count(t1)'] += 1                    
                # T2: 
                else:
                    courseList[index]['review_count(t2)'] += 1
                    courseList[index]['review_value(t2)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t2)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t2)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t2)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t2)'] += 1
                    else:
                        courseList[index]['high_review_count(t2)'] += 1                    
            
            elif date.year == 2015:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t2)'] += 1
                    courseList[index]['review_value(t2)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t2)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t2)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t2)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t2)'] += 1
                    else:
                        courseList[index]['high_review_count(t2)'] += 1                    
                # T3: 
                else:
                    courseList[index]['review_count(t3)'] += 1
                    courseList[index]['review_value(t3)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t3)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t3)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t3)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t3)'] += 1
                    else:
                        courseList[index]['high_review_count(t3)'] += 1                    
            elif date.year == 2016:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t3)'] += 1
                    courseList[index]['review_value(t3)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t3)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t3)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t3)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t3)'] += 1
                    else:
                        courseList[index]['high_review_count(t3)'] += 1                    
                # T4: 
                else:
                    courseList[index]['review_count(t4)'] += 1
                    courseList[index]['review_value(t4)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t4)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t4)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t4)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t4)'] += 1
                    else:
                        courseList[index]['high_review_count(t4)'] += 1                    
            elif date.year == 2017:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t4)'] += 1
                    courseList[index]['review_value(t4)'] += int(review['single_rating_value'])  
                    courseList[index]['review_length(t4)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t4)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t4)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t4)'] += 1
                    else:
                        courseList[index]['high_review_count(t4)'] += 1

# %%
#### iterate review data and set reviewCount by each time period
#### T1: 13.7~14.6 / T2; 14.7.~15.6 / T3: 15.7~16.6. / T4: 16.7~17.6 

for index, course in enumerate(courseList):
    
    
    for review in reviewList:
        
        temp_review_value = int(review['single_rating_value'])
        
        
        # review데이터의 course_url 과 course데이터의 url이 일치할 경우 review_count(tx)/review_value(tx)값 증가
        if review['url'] == course['url']:
                    
            date = datetime.datetime.strptime(review['review_date'], "%Y-%m-%d") 
           
            if date.year == 2013:
                # T1: 
                if date.month > 6 and date.month <= 12:
                    courseList[index]['review_count(t1)'] += 1
                    courseList[index]['review_value(t1)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t1)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t1)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t1)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t1)'] += 1
                    else:
                        courseList[index]['high_review_count(t1)'] += 1
                                
            elif date.year == 2014:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t1)'] += 1
                    courseList[index]['review_value(t1)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t1)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t1)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t1)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t1)'] += 1
                    else:
                        courseList[index]['high_review_count(t1)'] += 1                    
                # T2: 
                else:
                    courseList[index]['review_count(t2)'] += 1
                    courseList[index]['review_value(t2)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t2)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t2)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t2)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t2)'] += 1
                    else:
                        courseList[index]['high_review_count(t2)'] += 1                    
            
            elif date.year == 2015:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t2)'] += 1
                    courseList[index]['review_value(t2)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t2)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t2)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t2)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t2)'] += 1
                    else:
                        courseList[index]['high_review_count(t2)'] += 1                    
                # T3: 
                else:
                    courseList[index]['review_count(t3)'] += 1
                    courseList[index]['review_value(t3)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t3)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t3)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t3)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t3)'] += 1
                    else:
                        courseList[index]['high_review_count(t3)'] += 1                    
            elif date.year == 2016:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t3)'] += 1
                    courseList[index]['review_value(t3)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t3)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t3)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t3)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t3)'] += 1
                    else:
                        courseList[index]['high_review_count(t3)'] += 1                    
                # T4: 
                else:
                    courseList[index]['review_count(t4)'] += 1
                    courseList[index]['review_value(t4)'] += int(review['single_rating_value'])
                    courseList[index]['review_length(t4)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t4)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t4)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t4)'] += 1
                    else:
                        courseList[index]['high_review_count(t4)'] += 1                    
            elif date.year == 2017:
                
                if date.month > 0 and date.month < 7:
                    courseList[index]['review_count(t4)'] += 1
                    courseList[index]['review_value(t4)'] += int(review['single_rating_value'])  
                    courseList[index]['review_length(t4)'] += len(review['review_contents'])
                    
                    if review['helpful_rate'] != "0":
                        courseList[index]['helpful_review_count(t4)'] += int(review['helpful_rate'])
                    
                    if temp_review_value > 0 and temp_review_value < 3:
                        courseList[index]['low_review_count(t4)'] += 1
                    elif temp_review_value == 3:
                        courseList[index]['moderate_review_count(t4)'] += 1
                    else:
                        courseList[index]['high_review_count(t4)'] += 1
